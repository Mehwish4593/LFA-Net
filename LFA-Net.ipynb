# %%
import tensorflow as tf
tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_2851289/897549616.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
TF_ENABLE_ONEDNN_OPTS=0

# %%
# import zipfile

# filename = "/homes/imransharif/Mehwish/Dataset/DRIVE_Final_880.zip"

# with zipfile.ZipFile(filename, 'r') as zip_ref:
#     zip_ref.extractall()
#     print('Done')

# %%
import os
# !pip install keras-preprocessing
# !pip install scikit-image
import tensorflow as tf
import time
#import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

#from tqdm import tqdm_notebook, tnrange
from itertools import chain
# from skimage.io import imread, imshow, concatenate_images
# from skimage.transform import resize
# from skimage.morphology import label
from sklearn.model_selection import train_test_split
# import imageio

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout, Resizing
from keras.layers import Lambda, RepeatVector, Reshape
from keras.layers import Conv2D, Conv2DTranspose
from keras.layers import MaxPooling2D, GlobalMaxPool2D, AveragePooling2D
from keras.regularizers import l2
#from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
#from keras_preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import *
from keras.losses import *
from keras import backend as keras

from keras.utils import plot_model

from keras_preprocessing.image import array_to_img, img_to_array, load_img
import cv2
# import skimage.io as io

import glob
from PIL import Image
# import skimage
from keras.initializers import Constant

# from skimage.morphology import disk
from sklearn.metrics import confusion_matrix
# from skimage.measure import label, regionprops
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import jaccard_score

from keras import backend as K
from keras import layers, models
import zipfile
import random
import sys

# import skimage.io                           #Used for imshow function
# import skimage.transform                    #Used for resize function
# from skimage.morphology import label        #Used for Run-Length-Encoding RLE to create final submission
import matplotlib.pyplot as plt
from keras.layers import Concatenate, add

import warnings
warnings.filterwarnings("ignore")
random.seed(42)
np.random.seed(42)
tf.random.set_seed(42)
from keras.losses import binary_crossentropy
from sklearn.metrics import precision_recall_curve
# Out:
# /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# Requirement already satisfied: keras-preprocessing in /homes/imransharif/.local/lib/python3.10/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /opt/software/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages (from keras-preprocessing) (1.22.3)
# Requirement already satisfied: six>=1.9.0 in /homes/imransharif/.local/lib/python3.10/site-packages (from keras-preprocessing) (1.16.0)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# Requirement already satisfied: scikit-image in /homes/imransharif/.local/lib/python3.10/site-packages (0.23.2)
# Collecting numpy>=1.23 (from scikit-image)
#   Using cached numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.9 (from scikit-image)
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: networkx>=2.8 in /opt/software/software/networkx/2.8.4-foss-2022a/lib/python3.10/site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: pillow>=9.1 in /opt/software/software/Pillow/9.1.1-GCCcore-11.3.0/lib/python3.10/site-packages (from scikit-image) (9.1.1)
# Requirement already satisfied: imageio>=2.33 in /homes/imransharif/.local/lib/python3.10/site-packages (from scikit-image) (2.34.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /homes/imransharif/.local/lib/python3.10/site-packages (from scikit-image) (2024.4.24)
# Requirement already satisfied: packaging>=21 in /homes/imransharif/.local/lib/python3.10/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: lazy-loader>=0.4 in /homes/imransharif/.local/lib/python3.10/site-packages (from scikit-image) (0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /homes/imransharif/.local/lib/python3.10/site-packages (from packaging>=21->scikit-image) (3.0.9)
# Using cached numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# Installing collected packages: numpy, scipy
#   WARNING: The scripts f2py and numpy-config are installed in '/homes/imransharif/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcvit-tensorflow 1.2.1 requires absl-py==1.2.0, but you have absl-py 1.4.0 which is incompatible.
# gcvit-tensorflow 1.2.1 requires cachetools==5.2.0, but you have cachetools 5.2.1 which is incompatible.
# gcvit-tensorflow 1.2.1 requires flatbuffers==1.12, but you have flatbuffers 20240208003218 which is incompatible.
# gcvit-tensorflow 1.2.1 requires google-auth==2.11.0, but you have google-auth 2.16.0 which is incompatible.
# gcvit-tensorflow 1.2.1 requires grpcio==1.47.0, but you have grpcio 1.51.1 which is incompatible.
# gcvit-tensorflow 1.2.1 requires keras==2.9.0, but you have keras 2.11.0 which is incompatible.
# gcvit-tensorflow 1.2.1 requires numpy==1.23.1, but you have numpy 2.2.5 which is incompatible.
# gcvit-tensorflow 1.2.1 requires oauthlib==3.2.0, but you have oauthlib 3.2.2 which is incompatible.
# gcvit-tensorflow 1.2.1 requires tensorboard==2.9.1, but you have tensorboard 2.11.1 which is incompatible.
# gcvit-tensorflow 1.2.1 requires tensorflow==2.9.0, but you have tensorflow 2.11.0 which is incompatible.
# gcvit-tensorflow 1.2.1 requires tensorflow-estimator==2.9.0, but you have tensorflow-estimator 2.11.0 which is incompatible.
# gcvit-tensorflow 1.2.1 requires typing-extensions==4.3.0, but you have typing-extensions 4.13.2 which is incompatible.
# tb-nightly 2.18.0a20240722 requires protobuf!=4.24.0,<5.0.0,>=3.19.6, but you have protobuf 3.19.4 which is incompatible.
# tb-nightly 2.18.0a20240722 requires tensorboard-data-server<0.8.0,>=0.7.0, but you have tensorboard-data-server 0.6.1 which is incompatible.
# tensorflow-datasets 4.9.8 requires protobuf>=3.20, but you have protobuf 3.19.4 which is incompatible.
# tensorflow-hub 0.16.1 requires protobuf>=3.19.6, but you have protobuf 3.19.4 which is incompatible.
# tf-keras 2.16.0 requires tensorflow<2.17,>=2.16, but you have tensorflow 2.11.0 which is incompatible.
# tf-nightly 2.18.0.dev20240721 requires h5py>=3.10.0, but you have h5py 3.7.0 which is incompatible.
# tf-nightly 2.18.0.dev20240721 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.2.5 which is incompatible.
# tf-nightly 2.18.0.dev20240721 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.4 which is incompatible.
# tfswin 3.5.0 requires numpy<2.0.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# tfswin 3.5.0 requires tensorflow==2.16.*, but you have tensorflow 2.11.0 which is incompatible.
# torchvision 0.18.0 requires torch==2.3.0, but you have torch 1.12.1 which is incompatible.
# Successfully installed numpy-1.21.6 scipy-1.13.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip

# %%
# dataset_dir = '/content/drive/MyDrive/Colab_Notebooks/DRIVE_Augmented/DRIVE_BioNet-Augmented'
# os.listdir(dataset_dir)

# %%
import tensorflow as tf
import keras.backend as K

def dice_coef(y_true, y_pred, smooth=1e-6):
    """
    Compute Dice Coefficient for evaluating segmentation models.
    """
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    """
    Compute Dice Loss (1 - Dice Coefficient).
    """
    return 1 - dice_coef(y_true, y_pred)

def Jaccard_coef(y_true, y_pred, smooth=1e-6):
    """
    Compute Jaccard Index (Intersection over Union - IoU).
    """
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def Jaccard_coef_loss(y_true, y_pred):
    """
    Compute Jaccard Loss (1 - IoU).
    """
    return 1 - Jaccard_coef(y_true, y_pred)

def threshold_binarize(x, threshold=0.5):
    """
    Apply thresholding to predictions to convert them into binary outputs.
    """
    return tf.cast(x >= threshold, tf.float32)

def iou(y_true, y_pred, threshold=0.5, smooth=1e-6):
    """
    Compute Intersection over Union (IoU) after thresholding y_pred.
    """
    y_pred = threshold_binarize(y_pred, threshold)
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def sensitivity(y_true, y_pred):
    """
    Compute Sensitivity (Recall).
    """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    """
    Compute Specificity.
    """
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def  DiceLoss(y_true, y_pred, smooth=1e-6):
    """
    Compute Dice Loss for segmentation tasks.
    """
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    
    # Ensure shape match
    y_true_resized = tf.image.resize(y_true, (tf.shape(y_pred)[1], tf.shape(y_pred)[2]))
    
    intersection = tf.reduce_sum(y_pred * y_true_resized)
    denominator = tf.reduce_sum(y_pred**2) + tf.reduce_sum(y_true_resized**2)
    
    return 1 - (2. * intersection + smooth) / (denominator + smooth)

def bcc_Jaccard_coef_loss(y_true, y_pred):
    """
    Combined Dice Loss and IoU Loss for better segmentation performance.
    """
    iou_value = iou(y_true, y_pred, threshold=0.5)
    return DiceLoss(y_true, y_pred) + (1 - iou_value)

# %%
# model.compile(optimizer=tf.keras.optimizers.Adam(),
#               loss={'final_output1': DiceLoss},
#               metrics={'final_output1': [dice_coef, iou, sensitivity, specificity]})

# model.summary()

# %%
# tf.keras.utils.plot_model(
#     model,
#     show_shapes=False,
#     show_dtype=False,
#     show_layer_names=True,
#     rankdir='TB',
#     expand_nested=False,
#     dpi=46,
#     layer_range=None
# )

# %%
import numpy as geek
def sem_attention_block(inputs):
    shape=inputs.shape
    F2=Conv2D(shape[3],1, padding='same') (inputs)
    F2=BatchNormalization() (F2)
    F2=Activation('relu') (F2)
    x1=MaxPooling2D(pool_size=(shape[1],shape[2]),padding='same')(F2)
    x2=AveragePooling2D(pool_size=(shape[1],shape[2]),padding='same')(F2)
    con1 = Concatenate()([x1,x2])
    F3=Conv2D(shape[3],1, padding='same') (con1)
    F3=BatchNormalization() (F3)
    F33=Activation('relu') (F3)
    xa=GlobalAveragePooling2D(keepdims=True)(inputs)
    xa=Conv2D(shape[3],1, padding='same') (xa)
    xaa=BatchNormalization() (xa)
    xaa=Activation('sigmoid') (xaa)
    xm=Multiply()([F33,xaa])
    xam=Add()([inputs,xm])
    return xam

# %%
# !pip install mamba-ssm

# %%
import tensorflow as tf
from tensorflow.keras import layers

# -----------------------------------------------
# FOCAL MODULATION BLOCK
# -----------------------------------------------
def focal_modulation(inputs, gamma=2.0, alpha=0.25):
    num_channels = inputs.shape[-1]

    mean = layers.GlobalAveragePooling2D()(inputs)
    max_val = layers.GlobalMaxPooling2D()(inputs)

    modulation = (max_val - mean) * alpha
    modulation = layers.Reshape((1, 1, num_channels))(modulation)
    modulation = layers.Conv2D(filters=num_channels, kernel_size=1, activation='sigmoid')(modulation)

    scaled_inputs = layers.Multiply()([inputs, modulation])
    outputs = layers.Lambda(lambda x: x ** gamma)(scaled_inputs)
    return outputs

# -----------------------------------------------
# FOCAL MODULATION + CONTEXT AGGREGATION BLOCK
# -----------------------------------------------
def focal_modulation_context_aggregation(inputs, filters):
    filters = int(filters)

    conv1 = layers.Conv2D(filters, kernel_size=3, padding='same', activation='relu')(inputs)

    conv2 = layers.Conv2D(filters, kernel_size=1, activation='relu')(inputs)
    global_context = layers.GlobalAveragePooling2D()(conv2)
    global_context = layers.Reshape((1, 1, filters))(global_context)
    global_context = layers.Conv2D(filters, kernel_size=1, activation='sigmoid')(global_context)
    global_context = layers.Multiply()([conv1, global_context])

    FM = focal_modulation(global_context)

    concatenated = layers.Concatenate()([conv1, FM])
    return concatenated

# -----------------------------------------------
# MAMBA-INSPIRED BLOCK
# -----------------------------------------------
class VisionMambaInspired(tf.keras.layers.Layer):
    def __init__(self, dim, dropout_rate=0.1):
        super().__init__()
        self.norm1 = layers.LayerNormalization()
        self.token_mixer = tf.keras.Sequential([
            layers.DepthwiseConv2D(kernel_size=3, padding='same'),
            layers.Activation('gelu'),
            layers.Dropout(dropout_rate),
        ])
        self.norm2 = layers.LayerNormalization()
        self.channel_mixer = tf.keras.Sequential([
            layers.Dense(dim * 4),
            layers.Activation('gelu'),
            layers.Dropout(dropout_rate),
            layers.Dense(dim),
            layers.Dropout(dropout_rate),
        ])

    def call(self, x):
        shortcut = x
        x = self.norm1(x)
        x = self.token_mixer(x) + shortcut

        shortcut = x
        x = self.norm2(x)
        x = self.channel_mixer(x) + shortcut
        return x

# -----------------------------------------------
# FINAL COMBINED BLOCK FOR BOTTLENECK
# -----------------------------------------------
def LiteFusion_Attention(input_tensor, filters, padding="same"):
    # Project input channels
    input_tensor = layers.Conv2D(filters, (1, 1), padding=padding)(input_tensor)

    # LayerNorm + Conv
    x = layers.LayerNormalization()(input_tensor)
    x = layers.Conv2D(filters, kernel_size=(3, 3), padding=padding)(x)

    # Context aggregation with focal modulation
    x = focal_modulation_context_aggregation(x, filters)

    # Project back to match residual shape
    x = layers.Conv2D(filters, (1, 1), padding=padding)(x)

    # Residual connection
    out = layers.Add()([x, input_tensor])

    # Vision Mamba Block
    out = VisionMambaInspired(dim=filters)(out)

    return out
input_shape = (512,512,3)
# inputs = layers.Input(shape=input_shape)
# p = LiteFusion_Attention(inputs, filters=24)
# output = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid',name = 'final_output1')(p)
# model = models.Model(inputs=inputs, outputs=[output])
# model = LiteFusion_Attention(inputs, filters=32)
# model.summary()

# %%
from keras.layers import GlobalAveragePooling2D, GlobalMaxPooling2D, Reshape, Dense, multiply, Permute, Concatenate
from keras import backend as K


#  import numpy as np
def RA_attention_block(inputs,n_classes,k):
    shape=K.int_shape(inputs)
    # F=Conv2D(k*n_classes,1, padding='same') (inputs)
    F=Conv2D(k*n_classes,3, padding='same') (inputs)
    F=BatchNormalization() (F)
    F1=Activation('relu') (F)

    F2=F1

    x1=GlobalMaxPool2D()(F2)
    x2=GlobalAveragePooling2D()(F2)
    x = Multiply() ([x1,x2])
    x=Reshape((n_classes,k))(x)
    S=Lambda(lambda x: K.mean(x,axis=-1,keepdims=False)) (x)

    # x2=Reshape((n_classes,k)) (x)
    # S2=Lambda(lambda x: K.mean(x,axis=-1,keepdims=False))  (x2)
    # S= S1+S2
    x=Reshape((shape[1],shape[2],n_classes,k)) (F1)
    x=Lambda(lambda x: K.mean(x,axis=-1,keepdims=False))  (x)
    x=Multiply()([S,x])
    M=Lambda(lambda x: K.mean(x,axis=-1,keepdims=True))  (x)

    semantic=Multiply()([inputs,M])
    return semantic

def conv_block(input, out_channels, dropout_rate=0.5):
    # Multi-scale convolutions
    conv1x1 = layers.Conv2D(out_channels, kernel_size=1, padding='same', use_bias=False)(input)
    conv3x3 = layers.Conv2D(out_channels, kernel_size=3, padding='same', use_bias=False)(input)
    conv3x3_dilated = layers.Conv2D(out_channels, kernel_size=3, padding='same', use_bias=False, dilation_rate=2)(input)
    
    # Fuse multi-scale outputs by summing them
    x = conv1x1 + conv3x3 + conv3x3_dilated
    x = layers.LeakyReLU(alpha=0.1)(x)
#     x = Dropout(dropout_rate)(x)
    return x


def LiteFusion_UNet(input_shape, num_classes, feature_scale=2, dropout=0.5):
    # Define the input layer
    filters = [int(x / feature_scale) for x in [16,32,64]]
    inputs = layers.Input(shape=input_shape)

    # Encoder - Convolutional Blocks
    conv_block1 = conv_block(inputs, filters[0], dropout)
#     conv_block1 = layers.Conv2D(8, kernel_size=(3, 3), padding='same', activation='relu')(inputs)
    conv_block1 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block1)
    conv_block1 = layers.BatchNormalization()(conv_block1)

    conv_block2 = conv_block(conv_block1, filters[1], dropout)
#     conv_block2 = layers.Conv2D(16, kernel_size=(3, 3), padding='same', activation='relu')(conv_block1)
    conv_block2 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block2)
    conv_block2 = layers.BatchNormalization()(conv_block2)

    conv_block3 = conv_block(conv_block2, filters[2], dropout)
#     conv_block3 = layers.Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu')(conv_block2)
    conv_block3 = layers.MaxPooling2D(pool_size=(2, 2))(conv_block3)
    conv_block3 = layers.BatchNormalization()(conv_block3)

    attention_output = LiteFusion_Attention(conv_block3, filters=32)


    # Concatenate the Encoder Convolutional and Transformer blocks

    att1 = RA_attention_block(attention_output,1,16)
    fused_features = layers.Concatenate()([att1, attention_output])

    # Decoder - Upsampling Blocks
    decoder_block1 = layers.Conv2DTranspose(filters[2], kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(fused_features)
    att2 = RA_attention_block(conv_block2,1,16)
    decoder_block1 = layers.Concatenate()([att2, decoder_block1])
    decoder_block1 = layers.Conv2D(filters[2], kernel_size=(3, 3), padding='same', activation='relu')(decoder_block1)

    decoder_block2 = layers.Conv2DTranspose(filters[2], kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(decoder_block1)

    att3=RA_attention_block(conv_block1,1,16)
    decoder_block2 = layers.Concatenate()([att3, decoder_block2])
    decoder_block2 = layers.Conv2D(filters[2], kernel_size=(3, 3), padding='same', activation='relu')(decoder_block2)


    decoder_block3 = layers.Conv2DTranspose(filters[0], kernel_size=(3, 3), strides=(2, 2), padding='same', activation='relu')(decoder_block2)
    decoder_block3 = layers.Conv2D(filters[0], kernel_size=(3, 3), padding='same', activation='relu')(decoder_block3)
    # Decoder - Output Block
    output = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid',name = 'final_output1')(decoder_block3)
#     output_OD = layers.Conv2D(1, kernel_size=(1, 1), activation='sigmoid', name = 'final_output2')(decoder_block3)

    # Create the model
    model = models.Model(inputs=inputs, outputs=[output])

    return model

# Define the input shape for binary semantic segmentation
input_shape = (512,512,3)  # Example input shape for RGB images

# Create the TransFuse Encoder-Decoder model with 3 MaxPooling layers for binary semantic segmentation
model = LiteFusion_UNet(input_shape, 1, feature_scale=2, dropout=0.5)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 8)  24          ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 8)  216         ['input_1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 512, 512, 8)  0          ['conv2d[0][0]',
#  da)                                                              'conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 8)  216         ['input_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 512, 512, 8)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'conv2d_2[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 512, 512, 8)  0           ['tf.__operators__.add_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 8)  0           ['leaky_re_lu[0][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 8)  32         ['max_pooling2d[0][0]']
#  alization)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 16  128         ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 16  1152        ['batch_normalization[0][0]']
#                                 )
#
#  tf.__operators__.add_2 (TFOpLa  (None, 256, 256, 16  0          ['conv2d_3[0][0]',
#  mbda)                          )                                 'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 16  1152        ['batch_normalization[0][0]']
#                                 )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 256, 256, 16  0          ['tf.__operators__.add_2[0][0]',
#  mbda)                          )                                 'conv2d_5[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 256, 256, 16  0           ['tf.__operators__.add_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 16  0          ['leaky_re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 16  64         ['max_pooling2d_1[0][0]']
#  rmalization)                   )
#
#  conv2d_6 (Conv2D)              (None, 128, 128, 32  512         ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 128, 128, 32  4608        ['batch_normalization_1[0][0]']
#                                 )
#
#  tf.__operators__.add_4 (TFOpLa  (None, 128, 128, 32  0          ['conv2d_6[0][0]',
#  mbda)                          )                                 'conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 128, 128, 32  4608        ['batch_normalization_1[0][0]']
#                                 )
#
#  tf.__operators__.add_5 (TFOpLa  (None, 128, 128, 32  0          ['tf.__operators__.add_4[0][0]',
#  mbda)                          )                                 'conv2d_8[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 128, 128, 32  0           ['tf.__operators__.add_5[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 32)  0           ['leaky_re_lu_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 32)  128         ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 64, 64, 32)   1056        ['batch_normalization_2[0][0]']
#
#  layer_normalization (LayerNorm  (None, 64, 64, 32)  64          ['conv2d_9[0][0]']
#  alization)
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 32)   9248        ['layer_normalization[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 32)   1056        ['conv2d_10[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['conv2d_12[0][0]']
#  alAveragePooling2D)
#
#  reshape (Reshape)              (None, 1, 1, 32)     0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 32)   9248        ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 1, 1, 32)     1056        ['reshape[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 32)   0           ['conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  global_max_pooling2d (GlobalMa  (None, 32)          0           ['multiply[0][0]']
#  xPooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 32)          0           ['multiply[0][0]']
#  obalAveragePooling2D)
#
#  conv2d_16 (Conv2D)             (None, 64, 64, 16)   4624        ['batch_normalization_2[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 32)           0           ['global_max_pooling2d[0][0]',
#                                                                   'global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 16)  64          ['conv2d_16[0][0]']
#  rmalization)
#
#  tf.math.multiply (TFOpLambda)  (None, 32)           0           ['tf.math.subtract[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 64, 64, 16)   0           ['batch_normalization_3[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 1, 32)     0           ['tf.math.multiply[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 16  64         ['conv2d_17[0][0]']
#  rmalization)                   )
#
#  global_max_pooling2d_1 (Global  (None, 16)          0           ['activation_2[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_2 (Gl  (None, 16)          0           ['activation_2[0][0]']
#  obalAveragePooling2D)
#
#  conv2d_14 (Conv2D)             (None, 1, 1, 32)     1056        ['reshape_1[0][0]']
#
#  activation_3 (Activation)      (None, 128, 128, 16  0           ['batch_normalization_4[0][0]']
#                                 )
#
#  multiply_2 (Multiply)          (None, 16)           0           ['global_max_pooling2d_1[0][0]',
#                                                                   'global_average_pooling2d_2[0][0
#                                                                  ]']
#
#  multiply_1 (Multiply)          (None, 64, 64, 32)   0           ['multiply[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 16  1168        ['batch_normalization[0][0]']
#                                 )
#
#  global_max_pooling2d_2 (Global  (None, 16)          0           ['activation_3[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_3 (Gl  (None, 16)          0           ['activation_3[0][0]']
#  obalAveragePooling2D)
#
#  reshape_2 (Reshape)            (None, 1, 16)        0           ['multiply_2[0][0]']
#
#  reshape_3 (Reshape)            (None, 64, 64, 1, 1  0           ['activation_2[0][0]']
#                                 6)
#
#  lambda (Lambda)                (None, 64, 64, 32)   0           ['multiply_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 256, 256, 16  64         ['conv2d_19[0][0]']
#  rmalization)                   )
#
#  multiply_5 (Multiply)          (None, 16)           0           ['global_max_pooling2d_2[0][0]',
#                                                                   'global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  lambda_1 (Lambda)              (None, 1)            0           ['reshape_2[0][0]']
#
#  lambda_2 (Lambda)              (None, 64, 64, 1)    0           ['reshape_3[0][0]']
#
#  concatenate (Concatenate)      (None, 64, 64, 64)   0           ['conv2d_11[0][0]',
#                                                                   'lambda[0][0]']
#
#  activation_4 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_5[0][0]']
#                                 )
#
#  reshape_4 (Reshape)            (None, 1, 16)        0           ['multiply_5[0][0]']
#
#  reshape_5 (Reshape)            (None, 128, 128, 1,  0           ['activation_3[0][0]']
#                                  16)
#
#  multiply_3 (Multiply)          (None, 64, 64, 1)    0           ['lambda_1[0][0]',
#                                                                   'lambda_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   2080        ['concatenate[0][0]']
#
#  global_max_pooling2d_3 (Global  (None, 16)          0           ['activation_4[0][0]']
#  MaxPooling2D)
#
#  global_average_pooling2d_4 (Gl  (None, 16)          0           ['activation_4[0][0]']
#  obalAveragePooling2D)
#
#  lambda_4 (Lambda)              (None, 1)            0           ['reshape_4[0][0]']
#
#  lambda_5 (Lambda)              (None, 128, 128, 1)  0           ['reshape_5[0][0]']
#
#  lambda_3 (Lambda)              (None, 64, 64, 1)    0           ['multiply_3[0][0]']
#
#  add (Add)                      (None, 64, 64, 32)   0           ['conv2d_15[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  multiply_8 (Multiply)          (None, 16)           0           ['global_max_pooling2d_3[0][0]',
#                                                                   'global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  multiply_6 (Multiply)          (None, 128, 128, 1)  0           ['lambda_4[0][0]',
#                                                                   'lambda_5[0][0]']
#
#  multiply_4 (Multiply)          (None, 64, 64, 32)   0           ['batch_normalization_2[0][0]',
#                                                                   'lambda_3[0][0]']
#
#  vision_mamba_inspired (VisionM  (None, 64, 64, 32)  8800        ['add[0][0]']
#  ambaInspired)
#
#  reshape_6 (Reshape)            (None, 1, 16)        0           ['multiply_8[0][0]']
#
#  reshape_7 (Reshape)            (None, 256, 256, 1,  0           ['activation_4[0][0]']
#                                  16)
#
#  lambda_6 (Lambda)              (None, 128, 128, 1)  0           ['multiply_6[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 64)   0           ['multiply_4[0][0]',
#                                                                   'vision_mamba_inspired[0][0]']
#
#  lambda_7 (Lambda)              (None, 1)            0           ['reshape_6[0][0]']
#
#  lambda_8 (Lambda)              (None, 256, 256, 1)  0           ['reshape_7[0][0]']
#
#  multiply_7 (Multiply)          (None, 128, 128, 16  0           ['batch_normalization_1[0][0]',
#                                 )                                 'lambda_6[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 128, 128, 32  18464      ['concatenate_1[0][0]']
#  ose)                           )
#
#  multiply_9 (Multiply)          (None, 256, 256, 1)  0           ['lambda_7[0][0]',
#                                                                   'lambda_8[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 48  0           ['multiply_7[0][0]',
#                                 )                                 'conv2d_transpose[0][0]']
#
#  lambda_9 (Lambda)              (None, 256, 256, 1)  0           ['multiply_9[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  13856       ['concatenate_2[0][0]']
#                                 )
#
#  multiply_10 (Multiply)         (None, 256, 256, 8)  0           ['batch_normalization[0][0]',
#                                                                   'lambda_9[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 32  9248       ['conv2d_18[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 40  0           ['multiply_10[0][0]',
#                                 )                                 'conv2d_transpose_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 32  11552       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 512, 512, 8)  2312       ['conv2d_20[0][0]']
#  spose)
#
#  conv2d_21 (Conv2D)             (None, 512, 512, 8)  584         ['conv2d_transpose_2[0][0]']
#
#  final_output1 (Conv2D)         (None, 512, 512, 1)  9           ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 110,833
# Trainable params: 110,625
# Non-trainable params: 208
# __________________________________________________________________________________________________

# %%
train_data ='' #data path
valid_data = ''

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from skimage.transform import resize

# Set the desired image dimensions
im_height = 512
im_width = 512

# Function to get and resize train images and masks for binary segmentation
def get_data(path):
    # Paths to images and masks directories
    images_paths = os.path.join(path, 'images')
    masks_path_BV = os.path.join(path, 'GT_BV')

    # Get the list of image and mask files, sorted for consistency
    images_ids = sorted(os.listdir(images_paths))
    mask1_ids = sorted(os.listdir(masks_path_BV))

    # Initialize arrays to hold the images and masks
    X = np.zeros((len(images_ids), im_height, im_width, 3), dtype=np.float32)  # For RGB images
    y1 = np.zeros((len(mask1_ids), im_height, im_width, 1), dtype=np.float32)  # For binary masks

    print('Getting and resizing images ... ')
    for n in range(len(images_ids)):
        try:
            # Load and resize the images
            img = img_to_array(load_img(os.path.join(images_paths, images_ids[n]), grayscale=False))  # Load as RGB
            x_img = resize(img, (im_height, im_width, 3), mode='constant', preserve_range=True)  # Resize image

            # Load and resize the masks
            mask_BV = img_to_array(load_img(os.path.join(masks_path_BV, mask1_ids[n]), grayscale=True))  # Load as grayscale
            mask_BV = resize(mask_BV, (im_height, im_width, 1), mode='constant', preserve_range=True)  # Resize mask

            # Normalize the image and mask values to the range [0, 1]
            X[n] = x_img / 255.0
            y1[n] = mask_BV / 255.0
        except Exception as e:
            # Handle non-image files or other loading issues
            print(f"Skipping file {images_ids[n]} or {mask1_ids[n]} due to an error: {e}")
            continue

    print('Done!')
    return X, y1

# Example usage:
# train_data = "path_to_your_data_folder"  # Replace with the path to your data directory
# X, y1 = get_data(train_data)
# print("X_train shape:", X.shape)
# print("y1_train shape:", y1.shape)

# %%
X, y1 = get_data(train_data)

print("X_train shape:", X.shape)
print("y1_train shape:", y1.shape)
# Out:
# Getting and resizing images ...
# Done!
# X_train shape: (880, 512, 512, 3)
# y1_train shape: (880, 512, 512, 1)

# %%
# prompt: ADD TRAIN TEST SPLIT AND PRINT SHAPES

# Get and resize train images and masks

X_train, X_test, y_train, y_test = train_test_split(X, y1, test_size=0.20, random_state=42)


# Print the shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("y1_train shape:", y_train.shape)
print("X_test shape:", X_test.shape)
print("y1_test shape:", y_test.shape)
# Out:
# X_train shape: (704, 512, 512, 3)
# y1_train shape: (704, 512, 512, 1)
# X_test shape: (176, 512, 512, 3)
# y1_test shape: (176, 512, 512, 1)

# %%
# prompt: convert masks into logical values and print shapes

y_train = np.array(y_train > 0.5, dtype=np.uint8)
y_test = np.array(y_test > 0.5, dtype=np.uint8)
# y2_train_od = np.array(y2_train_od > 0.5, dtype=np.uint8)
# y2_test_od = np.array(y2_test_od > 0.5, dtype=np.uint8)

# %%
# # prompt: display masks and print unique values

# ix = random.randint(0, len(X_train))
# imshow(X_train[ix])
# plt.show()
# imshow(np.squeeze(y_train[ix]))
# plt.show()


# print(np.unique(y_train[ix]))
# print(np.unique(y_test[ix]))

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint
nb_epoch = 300
batch_size=16
earlystopper = EarlyStopping(patience=10, verbose=1)
# Append '.weights.h5' to the filename
checkpoint = ModelCheckpoint('LiteFusion-Net_DRIVE.h5',
                             verbose=1, save_best_only=True,save_weights_only=True)
callbacks = [checkpoint]

# %%
# Import necessary libraries
from keras.optimizers import Adam
import tensorflow as tf
# model.compile(optimizer=Adam(0.002), loss=DiceLoss, metrics=['accuracy',dice_coef, Jaccard_coef,sensitivity, specificity])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss=DiceLoss,  # Ensure this is a valid loss function and not None
    metrics=['accuracy', dice_coef, Jaccard_coef]  # Ensure metrics are properly defined
)

# %%
results = model.fit(
    X_train,
    y_train,  # Pass y_train directly without brackets
    batch_size=batch_size,
    epochs=nb_epoch,
    callbacks=callbacks,
    validation_data=(X_test, y_test)  # Pass y_test directly without brackets
)
# Out:
# Epoch 1/300
# 2025-05-01 20:05:56.349663: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/vision_mamba_inspired/sequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 44/44 [==============================] - ETA: 0s - loss: 0.1585 - accuracy: 0.9668 - dice_coef: 0.7354 - Jaccard_coef: 0.5817
# Epoch 1: val_loss improved from inf to 0.15674, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 26s 265ms/step - loss: 0.1585 - accuracy: 0.9668 - dice_coef: 0.7354 - Jaccard_coef: 0.5817 - val_loss: 0.1567 - val_accuracy: 0.9673 - val_dice_coef: 0.7322 - val_Jaccard_coef: 0.5777
# Epoch 2/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9679 - dice_coef: 0.7435 - Jaccard_coef: 0.5919
# Epoch 2: val_loss improved from 0.15674 to 0.15666, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1528 - accuracy: 0.9679 - dice_coef: 0.7435 - Jaccard_coef: 0.5919 - val_loss: 0.1567 - val_accuracy: 0.9676 - val_dice_coef: 0.7338 - val_Jaccard_coef: 0.5797
# Epoch 3/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9681 - dice_coef: 0.7447 - Jaccard_coef: 0.5933
# Epoch 3: val_loss improved from 0.15666 to 0.15381, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 232ms/step - loss: 0.1517 - accuracy: 0.9681 - dice_coef: 0.7447 - Jaccard_coef: 0.5933 - val_loss: 0.1538 - val_accuracy: 0.9680 - val_dice_coef: 0.7421 - val_Jaccard_coef: 0.5902
# Epoch 4/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9681 - dice_coef: 0.7457 - Jaccard_coef: 0.5946
# Epoch 4: val_loss did not improve from 0.15381
# 44/44 [==============================] - 10s 228ms/step - loss: 0.1514 - accuracy: 0.9681 - dice_coef: 0.7457 - Jaccard_coef: 0.5946 - val_loss: 0.1543 - val_accuracy: 0.9680 - val_dice_coef: 0.7443 - val_Jaccard_coef: 0.5929
# Epoch 5/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1502 - accuracy: 0.9684 - dice_coef: 0.7476 - Jaccard_coef: 0.5970
# Epoch 5: val_loss did not improve from 0.15381
# 44/44 [==============================] - 10s 228ms/step - loss: 0.1502 - accuracy: 0.9684 - dice_coef: 0.7476 - Jaccard_coef: 0.5970 - val_loss: 0.1541 - val_accuracy: 0.9676 - val_dice_coef: 0.7383 - val_Jaccard_coef: 0.5854
# Epoch 6/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9684 - dice_coef: 0.7475 - Jaccard_coef: 0.5969
# Epoch 6: val_loss improved from 0.15381 to 0.15370, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 248ms/step - loss: 0.1501 - accuracy: 0.9684 - dice_coef: 0.7475 - Jaccard_coef: 0.5969 - val_loss: 0.1537 - val_accuracy: 0.9684 - val_dice_coef: 0.7481 - val_Jaccard_coef: 0.5977
# Epoch 7/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1494 - accuracy: 0.9686 - dice_coef: 0.7480 - Jaccard_coef: 0.5975
# Epoch 7: val_loss improved from 0.15370 to 0.15309, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 244ms/step - loss: 0.1494 - accuracy: 0.9686 - dice_coef: 0.7480 - Jaccard_coef: 0.5975 - val_loss: 0.1531 - val_accuracy: 0.9684 - val_dice_coef: 0.7497 - val_Jaccard_coef: 0.5998
# Epoch 8/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1492 - accuracy: 0.9686 - dice_coef: 0.7487 - Jaccard_coef: 0.5985
# Epoch 8: val_loss did not improve from 0.15309
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1492 - accuracy: 0.9686 - dice_coef: 0.7487 - Jaccard_coef: 0.5985 - val_loss: 0.1533 - val_accuracy: 0.9679 - val_dice_coef: 0.7491 - val_Jaccard_coef: 0.5990
# Epoch 9/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9688 - dice_coef: 0.7501 - Jaccard_coef: 0.6002
# Epoch 9: val_loss improved from 0.15309 to 0.15296, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 242ms/step - loss: 0.1483 - accuracy: 0.9688 - dice_coef: 0.7501 - Jaccard_coef: 0.6002 - val_loss: 0.1530 - val_accuracy: 0.9684 - val_dice_coef: 0.7441 - val_Jaccard_coef: 0.5927
# Epoch 10/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1486 - accuracy: 0.9687 - dice_coef: 0.7503 - Jaccard_coef: 0.6005
# Epoch 10: val_loss improved from 0.15296 to 0.15255, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 244ms/step - loss: 0.1486 - accuracy: 0.9687 - dice_coef: 0.7503 - Jaccard_coef: 0.6005 - val_loss: 0.1526 - val_accuracy: 0.9681 - val_dice_coef: 0.7448 - val_Jaccard_coef: 0.5935
# Epoch 11/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 0.9688 - dice_coef: 0.7506 - Jaccard_coef: 0.6008
# Epoch 11: val_loss improved from 0.15255 to 0.15208, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 236ms/step - loss: 0.1480 - accuracy: 0.9688 - dice_coef: 0.7506 - Jaccard_coef: 0.6008 - val_loss: 0.1521 - val_accuracy: 0.9686 - val_dice_coef: 0.7440 - val_Jaccard_coef: 0.5925
# Epoch 12/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9687 - dice_coef: 0.7501 - Jaccard_coef: 0.6003
# Epoch 12: val_loss did not improve from 0.15208
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1483 - accuracy: 0.9687 - dice_coef: 0.7501 - Jaccard_coef: 0.6003 - val_loss: 0.1531 - val_accuracy: 0.9683 - val_dice_coef: 0.7446 - val_Jaccard_coef: 0.5933
# Epoch 13/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9689 - dice_coef: 0.7509 - Jaccard_coef: 0.6012
# Epoch 13: val_loss did not improve from 0.15208
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1475 - accuracy: 0.9689 - dice_coef: 0.7509 - Jaccard_coef: 0.6012 - val_loss: 0.1528 - val_accuracy: 0.9680 - val_dice_coef: 0.7503 - val_Jaccard_coef: 0.6006
# Epoch 14/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9690 - dice_coef: 0.7520 - Jaccard_coef: 0.6026
# Epoch 14: val_loss improved from 0.15208 to 0.15154, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 235ms/step - loss: 0.1471 - accuracy: 0.9690 - dice_coef: 0.7520 - Jaccard_coef: 0.6026 - val_loss: 0.1515 - val_accuracy: 0.9683 - val_dice_coef: 0.7483 - val_Jaccard_coef: 0.5980
# Epoch 15/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9689 - dice_coef: 0.7516 - Jaccard_coef: 0.6021
# Epoch 15: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1477 - accuracy: 0.9689 - dice_coef: 0.7516 - Jaccard_coef: 0.6021 - val_loss: 0.1533 - val_accuracy: 0.9676 - val_dice_coef: 0.7438 - val_Jaccard_coef: 0.5923
# Epoch 16/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9690 - dice_coef: 0.7518 - Jaccard_coef: 0.6024
# Epoch 16: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1472 - accuracy: 0.9690 - dice_coef: 0.7518 - Jaccard_coef: 0.6024 - val_loss: 0.1582 - val_accuracy: 0.9686 - val_dice_coef: 0.7513 - val_Jaccard_coef: 0.6019
# Epoch 17/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1472 - accuracy: 0.9690 - dice_coef: 0.7519 - Jaccard_coef: 0.6025
# Epoch 17: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1472 - accuracy: 0.9690 - dice_coef: 0.7519 - Jaccard_coef: 0.6025 - val_loss: 0.1527 - val_accuracy: 0.9682 - val_dice_coef: 0.7438 - val_Jaccard_coef: 0.5923
# Epoch 18/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1460 - accuracy: 0.9692 - dice_coef: 0.7534 - Jaccard_coef: 0.6045
# Epoch 18: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1460 - accuracy: 0.9692 - dice_coef: 0.7534 - Jaccard_coef: 0.6045 - val_loss: 0.1522 - val_accuracy: 0.9686 - val_dice_coef: 0.7450 - val_Jaccard_coef: 0.5938
# Epoch 19/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9692 - dice_coef: 0.7535 - Jaccard_coef: 0.6045
# Epoch 19: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1461 - accuracy: 0.9692 - dice_coef: 0.7535 - Jaccard_coef: 0.6045 - val_loss: 0.1525 - val_accuracy: 0.9685 - val_dice_coef: 0.7496 - val_Jaccard_coef: 0.5997
# Epoch 20/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1458 - accuracy: 0.9693 - dice_coef: 0.7535 - Jaccard_coef: 0.6046
# Epoch 20: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1458 - accuracy: 0.9693 - dice_coef: 0.7535 - Jaccard_coef: 0.6046 - val_loss: 0.1517 - val_accuracy: 0.9685 - val_dice_coef: 0.7508 - val_Jaccard_coef: 0.6012
# Epoch 21/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1454 - accuracy: 0.9693 - dice_coef: 0.7545 - Jaccard_coef: 0.6058
# Epoch 21: val_loss did not improve from 0.15154
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1454 - accuracy: 0.9693 - dice_coef: 0.7545 - Jaccard_coef: 0.6058 - val_loss: 0.1519 - val_accuracy: 0.9685 - val_dice_coef: 0.7405 - val_Jaccard_coef: 0.5880
# Epoch 22/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9694 - dice_coef: 0.7558 - Jaccard_coef: 0.6075
# Epoch 22: val_loss improved from 0.15154 to 0.15094, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 242ms/step - loss: 0.1448 - accuracy: 0.9694 - dice_coef: 0.7558 - Jaccard_coef: 0.6075 - val_loss: 0.1509 - val_accuracy: 0.9690 - val_dice_coef: 0.7479 - val_Jaccard_coef: 0.5975
# Epoch 23/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1456 - accuracy: 0.9693 - dice_coef: 0.7542 - Jaccard_coef: 0.6054
# Epoch 23: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1456 - accuracy: 0.9693 - dice_coef: 0.7542 - Jaccard_coef: 0.6054 - val_loss: 0.1565 - val_accuracy: 0.9689 - val_dice_coef: 0.7471 - val_Jaccard_coef: 0.5965
# Epoch 24/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9693 - dice_coef: 0.7541 - Jaccard_coef: 0.6053
# Epoch 24: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1457 - accuracy: 0.9693 - dice_coef: 0.7541 - Jaccard_coef: 0.6053 - val_loss: 0.1520 - val_accuracy: 0.9688 - val_dice_coef: 0.7526 - val_Jaccard_coef: 0.6035
# Epoch 25/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9695 - dice_coef: 0.7559 - Jaccard_coef: 0.6077
# Epoch 25: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1448 - accuracy: 0.9695 - dice_coef: 0.7559 - Jaccard_coef: 0.6077 - val_loss: 0.1517 - val_accuracy: 0.9685 - val_dice_coef: 0.7447 - val_Jaccard_coef: 0.5934
# Epoch 26/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.9695 - dice_coef: 0.7550 - Jaccard_coef: 0.6065
# Epoch 26: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1447 - accuracy: 0.9695 - dice_coef: 0.7550 - Jaccard_coef: 0.6065 - val_loss: 0.1510 - val_accuracy: 0.9682 - val_dice_coef: 0.7474 - val_Jaccard_coef: 0.5969
# Epoch 27/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1445 - accuracy: 0.9695 - dice_coef: 0.7564 - Jaccard_coef: 0.6083
# Epoch 27: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1445 - accuracy: 0.9695 - dice_coef: 0.7564 - Jaccard_coef: 0.6083 - val_loss: 0.1511 - val_accuracy: 0.9685 - val_dice_coef: 0.7487 - val_Jaccard_coef: 0.5985
# Epoch 28/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7561 - Jaccard_coef: 0.6079
# Epoch 28: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7561 - Jaccard_coef: 0.6079 - val_loss: 0.1512 - val_accuracy: 0.9688 - val_dice_coef: 0.7542 - val_Jaccard_coef: 0.6056
# Epoch 29/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7561 - Jaccard_coef: 0.6079
# Epoch 29: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7561 - Jaccard_coef: 0.6079 - val_loss: 0.1516 - val_accuracy: 0.9689 - val_dice_coef: 0.7529 - val_Jaccard_coef: 0.6039
# Epoch 30/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7566 - Jaccard_coef: 0.6086
# Epoch 30: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1442 - accuracy: 0.9696 - dice_coef: 0.7566 - Jaccard_coef: 0.6086 - val_loss: 0.1512 - val_accuracy: 0.9689 - val_dice_coef: 0.7524 - val_Jaccard_coef: 0.6033
# Epoch 31/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1439 - accuracy: 0.9696 - dice_coef: 0.7572 - Jaccard_coef: 0.6093
# Epoch 31: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1439 - accuracy: 0.9696 - dice_coef: 0.7572 - Jaccard_coef: 0.6093 - val_loss: 0.1534 - val_accuracy: 0.9685 - val_dice_coef: 0.7516 - val_Jaccard_coef: 0.6022
# Epoch 32/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9696 - dice_coef: 0.7562 - Jaccard_coef: 0.6080
# Epoch 32: val_loss did not improve from 0.15094
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1443 - accuracy: 0.9696 - dice_coef: 0.7562 - Jaccard_coef: 0.6080 - val_loss: 0.1527 - val_accuracy: 0.9688 - val_dice_coef: 0.7557 - val_Jaccard_coef: 0.6075
# Epoch 33/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9697 - dice_coef: 0.7571 - Jaccard_coef: 0.6092
# Epoch 33: val_loss improved from 0.15094 to 0.15062, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 238ms/step - loss: 0.1434 - accuracy: 0.9697 - dice_coef: 0.7571 - Jaccard_coef: 0.6092 - val_loss: 0.1506 - val_accuracy: 0.9683 - val_dice_coef: 0.7478 - val_Jaccard_coef: 0.5973
# Epoch 34/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9698 - dice_coef: 0.7588 - Jaccard_coef: 0.6114
# Epoch 34: val_loss did not improve from 0.15062
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1431 - accuracy: 0.9698 - dice_coef: 0.7588 - Jaccard_coef: 0.6114 - val_loss: 0.1521 - val_accuracy: 0.9677 - val_dice_coef: 0.7371 - val_Jaccard_coef: 0.5838
# Epoch 35/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9698 - dice_coef: 0.7579 - Jaccard_coef: 0.6102
# Epoch 35: val_loss did not improve from 0.15062
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1431 - accuracy: 0.9698 - dice_coef: 0.7579 - Jaccard_coef: 0.6102 - val_loss: 0.1508 - val_accuracy: 0.9680 - val_dice_coef: 0.7471 - val_Jaccard_coef: 0.5965
# Epoch 36/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9699 - dice_coef: 0.7584 - Jaccard_coef: 0.6109
# Epoch 36: val_loss did not improve from 0.15062
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1428 - accuracy: 0.9699 - dice_coef: 0.7584 - Jaccard_coef: 0.6109 - val_loss: 0.1518 - val_accuracy: 0.9690 - val_dice_coef: 0.7535 - val_Jaccard_coef: 0.6046
# Epoch 37/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9697 - dice_coef: 0.7581 - Jaccard_coef: 0.6106
# Epoch 37: val_loss improved from 0.15062 to 0.14994, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 233ms/step - loss: 0.1434 - accuracy: 0.9697 - dice_coef: 0.7581 - Jaccard_coef: 0.6106 - val_loss: 0.1499 - val_accuracy: 0.9688 - val_dice_coef: 0.7462 - val_Jaccard_coef: 0.5953
# Epoch 38/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9699 - dice_coef: 0.7583 - Jaccard_coef: 0.6107
# Epoch 38: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1428 - accuracy: 0.9699 - dice_coef: 0.7583 - Jaccard_coef: 0.6107 - val_loss: 0.1512 - val_accuracy: 0.9682 - val_dice_coef: 0.7475 - val_Jaccard_coef: 0.5969
# Epoch 39/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9699 - dice_coef: 0.7594 - Jaccard_coef: 0.6121
# Epoch 39: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1423 - accuracy: 0.9699 - dice_coef: 0.7594 - Jaccard_coef: 0.6121 - val_loss: 0.1511 - val_accuracy: 0.9687 - val_dice_coef: 0.7473 - val_Jaccard_coef: 0.5966
# Epoch 40/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6115
# Epoch 40: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1426 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6115 - val_loss: 0.1508 - val_accuracy: 0.9690 - val_dice_coef: 0.7542 - val_Jaccard_coef: 0.6056
# Epoch 41/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6116
# Epoch 41: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1427 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6116 - val_loss: 0.1504 - val_accuracy: 0.9689 - val_dice_coef: 0.7530 - val_Jaccard_coef: 0.6040
# Epoch 42/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6116
# Epoch 42: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1426 - accuracy: 0.9699 - dice_coef: 0.7589 - Jaccard_coef: 0.6116 - val_loss: 0.1505 - val_accuracy: 0.9689 - val_dice_coef: 0.7510 - val_Jaccard_coef: 0.6015
# Epoch 43/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9700 - dice_coef: 0.7591 - Jaccard_coef: 0.6118
# Epoch 43: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1422 - accuracy: 0.9700 - dice_coef: 0.7591 - Jaccard_coef: 0.6118 - val_loss: 0.1505 - val_accuracy: 0.9686 - val_dice_coef: 0.7485 - val_Jaccard_coef: 0.5983
# Epoch 44/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9699 - dice_coef: 0.7587 - Jaccard_coef: 0.6113
# Epoch 44: val_loss did not improve from 0.14994
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1429 - accuracy: 0.9699 - dice_coef: 0.7587 - Jaccard_coef: 0.6113 - val_loss: 0.1503 - val_accuracy: 0.9685 - val_dice_coef: 0.7499 - val_Jaccard_coef: 0.6000
# Epoch 45/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9701 - dice_coef: 0.7598 - Jaccard_coef: 0.6127
# Epoch 45: val_loss improved from 0.14994 to 0.14958, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 237ms/step - loss: 0.1419 - accuracy: 0.9701 - dice_coef: 0.7598 - Jaccard_coef: 0.6127 - val_loss: 0.1496 - val_accuracy: 0.9684 - val_dice_coef: 0.7499 - val_Jaccard_coef: 0.6000
# Epoch 46/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9700 - dice_coef: 0.7598 - Jaccard_coef: 0.6128
# Epoch 46: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1418 - accuracy: 0.9700 - dice_coef: 0.7598 - Jaccard_coef: 0.6128 - val_loss: 0.1498 - val_accuracy: 0.9686 - val_dice_coef: 0.7554 - val_Jaccard_coef: 0.6071
# Epoch 47/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9701 - dice_coef: 0.7609 - Jaccard_coef: 0.6141
# Epoch 47: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1415 - accuracy: 0.9701 - dice_coef: 0.7609 - Jaccard_coef: 0.6141 - val_loss: 0.1502 - val_accuracy: 0.9685 - val_dice_coef: 0.7489 - val_Jaccard_coef: 0.5988
# Epoch 48/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9702 - dice_coef: 0.7610 - Jaccard_coef: 0.6143
# Epoch 48: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1412 - accuracy: 0.9702 - dice_coef: 0.7610 - Jaccard_coef: 0.6143 - val_loss: 0.1501 - val_accuracy: 0.9691 - val_dice_coef: 0.7581 - val_Jaccard_coef: 0.6106
# Epoch 49/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9702 - dice_coef: 0.7607 - Jaccard_coef: 0.6139
# Epoch 49: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1414 - accuracy: 0.9702 - dice_coef: 0.7607 - Jaccard_coef: 0.6139 - val_loss: 0.1503 - val_accuracy: 0.9688 - val_dice_coef: 0.7528 - val_Jaccard_coef: 0.6038
# Epoch 50/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9701 - dice_coef: 0.7609 - Jaccard_coef: 0.6141
# Epoch 50: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1414 - accuracy: 0.9701 - dice_coef: 0.7609 - Jaccard_coef: 0.6141 - val_loss: 0.1527 - val_accuracy: 0.9690 - val_dice_coef: 0.7411 - val_Jaccard_coef: 0.5888
# Epoch 51/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9701 - dice_coef: 0.7607 - Jaccard_coef: 0.6139
# Epoch 51: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1415 - accuracy: 0.9701 - dice_coef: 0.7607 - Jaccard_coef: 0.6139 - val_loss: 0.1501 - val_accuracy: 0.9687 - val_dice_coef: 0.7524 - val_Jaccard_coef: 0.6032
# Epoch 52/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1412 - accuracy: 0.9702 - dice_coef: 0.7613 - Jaccard_coef: 0.6147
# Epoch 52: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1412 - accuracy: 0.9702 - dice_coef: 0.7613 - Jaccard_coef: 0.6147 - val_loss: 0.1506 - val_accuracy: 0.9692 - val_dice_coef: 0.7517 - val_Jaccard_coef: 0.6023
# Epoch 53/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7621 - Jaccard_coef: 0.6158
# Epoch 53: val_loss did not improve from 0.14958
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7621 - Jaccard_coef: 0.6158 - val_loss: 0.1503 - val_accuracy: 0.9689 - val_dice_coef: 0.7524 - val_Jaccard_coef: 0.6032
# Epoch 54/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9703 - dice_coef: 0.7617 - Jaccard_coef: 0.6152
# Epoch 54: val_loss improved from 0.14958 to 0.14921, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 234ms/step - loss: 0.1406 - accuracy: 0.9703 - dice_coef: 0.7617 - Jaccard_coef: 0.6152 - val_loss: 0.1492 - val_accuracy: 0.9689 - val_dice_coef: 0.7537 - val_Jaccard_coef: 0.6049
# Epoch 55/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9703 - dice_coef: 0.7624 - Jaccard_coef: 0.6160
# Epoch 55: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1403 - accuracy: 0.9703 - dice_coef: 0.7624 - Jaccard_coef: 0.6160 - val_loss: 0.1501 - val_accuracy: 0.9691 - val_dice_coef: 0.7529 - val_Jaccard_coef: 0.6038
# Epoch 56/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7624 - Jaccard_coef: 0.6160
# Epoch 56: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7624 - Jaccard_coef: 0.6160 - val_loss: 0.1503 - val_accuracy: 0.9692 - val_dice_coef: 0.7522 - val_Jaccard_coef: 0.6029
# Epoch 57/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9703 - dice_coef: 0.7618 - Jaccard_coef: 0.6153
# Epoch 57: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1407 - accuracy: 0.9703 - dice_coef: 0.7618 - Jaccard_coef: 0.6153 - val_loss: 0.1524 - val_accuracy: 0.9692 - val_dice_coef: 0.7490 - val_Jaccard_coef: 0.5989
# Epoch 58/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7621 - Jaccard_coef: 0.6157
# Epoch 58: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1405 - accuracy: 0.9703 - dice_coef: 0.7621 - Jaccard_coef: 0.6157 - val_loss: 0.1495 - val_accuracy: 0.9686 - val_dice_coef: 0.7538 - val_Jaccard_coef: 0.6051
# Epoch 59/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9704 - dice_coef: 0.7625 - Jaccard_coef: 0.6162
# Epoch 59: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1402 - accuracy: 0.9704 - dice_coef: 0.7625 - Jaccard_coef: 0.6162 - val_loss: 0.1497 - val_accuracy: 0.9686 - val_dice_coef: 0.7526 - val_Jaccard_coef: 0.6035
# Epoch 60/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9704 - dice_coef: 0.7630 - Jaccard_coef: 0.6168
# Epoch 60: val_loss did not improve from 0.14921
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1399 - accuracy: 0.9704 - dice_coef: 0.7630 - Jaccard_coef: 0.6168 - val_loss: 0.1507 - val_accuracy: 0.9694 - val_dice_coef: 0.7556 - val_Jaccard_coef: 0.6073
# Epoch 61/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9705 - dice_coef: 0.7632 - Jaccard_coef: 0.6171
# Epoch 61: val_loss improved from 0.14921 to 0.14905, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 234ms/step - loss: 0.1400 - accuracy: 0.9705 - dice_coef: 0.7632 - Jaccard_coef: 0.6171 - val_loss: 0.1491 - val_accuracy: 0.9688 - val_dice_coef: 0.7514 - val_Jaccard_coef: 0.6020
# Epoch 62/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9703 - dice_coef: 0.7622 - Jaccard_coef: 0.6158
# Epoch 62: val_loss did not improve from 0.14905
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1406 - accuracy: 0.9703 - dice_coef: 0.7622 - Jaccard_coef: 0.6158 - val_loss: 0.1508 - val_accuracy: 0.9687 - val_dice_coef: 0.7561 - val_Jaccard_coef: 0.6080
# Epoch 63/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9704 - dice_coef: 0.7629 - Jaccard_coef: 0.6168
# Epoch 63: val_loss improved from 0.14905 to 0.14901, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 234ms/step - loss: 0.1400 - accuracy: 0.9704 - dice_coef: 0.7629 - Jaccard_coef: 0.6168 - val_loss: 0.1490 - val_accuracy: 0.9690 - val_dice_coef: 0.7547 - val_Jaccard_coef: 0.6062
# Epoch 64/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1404 - accuracy: 0.9704 - dice_coef: 0.7628 - Jaccard_coef: 0.6166
# Epoch 64: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1404 - accuracy: 0.9704 - dice_coef: 0.7628 - Jaccard_coef: 0.6166 - val_loss: 0.1514 - val_accuracy: 0.9688 - val_dice_coef: 0.7533 - val_Jaccard_coef: 0.6043
# Epoch 65/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9705 - dice_coef: 0.7633 - Jaccard_coef: 0.6172
# Epoch 65: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1396 - accuracy: 0.9705 - dice_coef: 0.7633 - Jaccard_coef: 0.6172 - val_loss: 0.1492 - val_accuracy: 0.9690 - val_dice_coef: 0.7509 - val_Jaccard_coef: 0.6014
# Epoch 66/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9706 - dice_coef: 0.7644 - Jaccard_coef: 0.6187
# Epoch 66: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1390 - accuracy: 0.9706 - dice_coef: 0.7644 - Jaccard_coef: 0.6187 - val_loss: 0.1494 - val_accuracy: 0.9693 - val_dice_coef: 0.7565 - val_Jaccard_coef: 0.6086
# Epoch 67/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9705 - dice_coef: 0.7637 - Jaccard_coef: 0.6178
# Epoch 67: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1396 - accuracy: 0.9705 - dice_coef: 0.7637 - Jaccard_coef: 0.6178 - val_loss: 0.1493 - val_accuracy: 0.9689 - val_dice_coef: 0.7526 - val_Jaccard_coef: 0.6035
# Epoch 68/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9704 - dice_coef: 0.7632 - Jaccard_coef: 0.6172
# Epoch 68: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1401 - accuracy: 0.9704 - dice_coef: 0.7632 - Jaccard_coef: 0.6172 - val_loss: 0.1514 - val_accuracy: 0.9691 - val_dice_coef: 0.7542 - val_Jaccard_coef: 0.6056
# Epoch 69/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1402 - accuracy: 0.9704 - dice_coef: 0.7624 - Jaccard_coef: 0.6161
# Epoch 69: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1402 - accuracy: 0.9704 - dice_coef: 0.7624 - Jaccard_coef: 0.6161 - val_loss: 0.1500 - val_accuracy: 0.9691 - val_dice_coef: 0.7517 - val_Jaccard_coef: 0.6023
# Epoch 70/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9705 - dice_coef: 0.7633 - Jaccard_coef: 0.6172
# Epoch 70: val_loss did not improve from 0.14901
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1397 - accuracy: 0.9705 - dice_coef: 0.7633 - Jaccard_coef: 0.6172 - val_loss: 0.1491 - val_accuracy: 0.9689 - val_dice_coef: 0.7556 - val_Jaccard_coef: 0.6074
# Epoch 71/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9706 - dice_coef: 0.7650 - Jaccard_coef: 0.6194
# Epoch 71: val_loss improved from 0.14901 to 0.14870, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 250ms/step - loss: 0.1390 - accuracy: 0.9706 - dice_coef: 0.7650 - Jaccard_coef: 0.6194 - val_loss: 0.1487 - val_accuracy: 0.9688 - val_dice_coef: 0.7517 - val_Jaccard_coef: 0.6023
# Epoch 72/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1393 - accuracy: 0.9706 - dice_coef: 0.7640 - Jaccard_coef: 0.6181
# Epoch 72: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1393 - accuracy: 0.9706 - dice_coef: 0.7640 - Jaccard_coef: 0.6181 - val_loss: 0.1509 - val_accuracy: 0.9687 - val_dice_coef: 0.7481 - val_Jaccard_coef: 0.5977
# Epoch 73/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6194
# Epoch 73: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6194 - val_loss: 0.1500 - val_accuracy: 0.9690 - val_dice_coef: 0.7548 - val_Jaccard_coef: 0.6064
# Epoch 74/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7643 - Jaccard_coef: 0.6186
# Epoch 74: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7643 - Jaccard_coef: 0.6186 - val_loss: 0.1503 - val_accuracy: 0.9693 - val_dice_coef: 0.7525 - val_Jaccard_coef: 0.6034
# Epoch 75/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9707 - dice_coef: 0.7656 - Jaccard_coef: 0.6202
# Epoch 75: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1387 - accuracy: 0.9707 - dice_coef: 0.7656 - Jaccard_coef: 0.6202 - val_loss: 0.1498 - val_accuracy: 0.9693 - val_dice_coef: 0.7498 - val_Jaccard_coef: 0.5999
# Epoch 76/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9706 - dice_coef: 0.7643 - Jaccard_coef: 0.6186
# Epoch 76: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1391 - accuracy: 0.9706 - dice_coef: 0.7643 - Jaccard_coef: 0.6186 - val_loss: 0.1491 - val_accuracy: 0.9689 - val_dice_coef: 0.7562 - val_Jaccard_coef: 0.6082
# Epoch 77/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6193
# Epoch 77: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1386 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6193 - val_loss: 0.1491 - val_accuracy: 0.9692 - val_dice_coef: 0.7500 - val_Jaccard_coef: 0.6002
# Epoch 78/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9707 - dice_coef: 0.7653 - Jaccard_coef: 0.6199
# Epoch 78: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1385 - accuracy: 0.9707 - dice_coef: 0.7653 - Jaccard_coef: 0.6199 - val_loss: 0.1497 - val_accuracy: 0.9692 - val_dice_coef: 0.7542 - val_Jaccard_coef: 0.6055
# Epoch 79/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1382 - accuracy: 0.9708 - dice_coef: 0.7661 - Jaccard_coef: 0.6209
# Epoch 79: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1382 - accuracy: 0.9708 - dice_coef: 0.7661 - Jaccard_coef: 0.6209 - val_loss: 0.1495 - val_accuracy: 0.9695 - val_dice_coef: 0.7595 - val_Jaccard_coef: 0.6124
# Epoch 80/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6194
# Epoch 80: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1389 - accuracy: 0.9707 - dice_coef: 0.7649 - Jaccard_coef: 0.6194 - val_loss: 0.1510 - val_accuracy: 0.9681 - val_dice_coef: 0.7436 - val_Jaccard_coef: 0.5921
# Epoch 81/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9707 - dice_coef: 0.7652 - Jaccard_coef: 0.6198
# Epoch 81: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1386 - accuracy: 0.9707 - dice_coef: 0.7652 - Jaccard_coef: 0.6198 - val_loss: 0.1488 - val_accuracy: 0.9691 - val_dice_coef: 0.7521 - val_Jaccard_coef: 0.6028
# Epoch 82/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1391 - accuracy: 0.9706 - dice_coef: 0.7642 - Jaccard_coef: 0.6184
# Epoch 82: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1391 - accuracy: 0.9706 - dice_coef: 0.7642 - Jaccard_coef: 0.6184 - val_loss: 0.1538 - val_accuracy: 0.9691 - val_dice_coef: 0.7495 - val_Jaccard_coef: 0.5995
# Epoch 83/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9707 - dice_coef: 0.7647 - Jaccard_coef: 0.6191
# Epoch 83: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1388 - accuracy: 0.9707 - dice_coef: 0.7647 - Jaccard_coef: 0.6191 - val_loss: 0.1491 - val_accuracy: 0.9689 - val_dice_coef: 0.7568 - val_Jaccard_coef: 0.6089
# Epoch 84/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9707 - dice_coef: 0.7652 - Jaccard_coef: 0.6197
# Epoch 84: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1387 - accuracy: 0.9707 - dice_coef: 0.7652 - Jaccard_coef: 0.6197 - val_loss: 0.1489 - val_accuracy: 0.9689 - val_dice_coef: 0.7566 - val_Jaccard_coef: 0.6087
# Epoch 85/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1385 - accuracy: 0.9707 - dice_coef: 0.7655 - Jaccard_coef: 0.6201
# Epoch 85: val_loss did not improve from 0.14870
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1385 - accuracy: 0.9707 - dice_coef: 0.7655 - Jaccard_coef: 0.6201 - val_loss: 0.1491 - val_accuracy: 0.9695 - val_dice_coef: 0.7562 - val_Jaccard_coef: 0.6081
# Epoch 86/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9709 - dice_coef: 0.7664 - Jaccard_coef: 0.6213
# Epoch 86: val_loss improved from 0.14870 to 0.14803, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 233ms/step - loss: 0.1378 - accuracy: 0.9709 - dice_coef: 0.7664 - Jaccard_coef: 0.6213 - val_loss: 0.1480 - val_accuracy: 0.9691 - val_dice_coef: 0.7522 - val_Jaccard_coef: 0.6030
# Epoch 87/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9709 - dice_coef: 0.7669 - Jaccard_coef: 0.6220
# Epoch 87: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1375 - accuracy: 0.9709 - dice_coef: 0.7669 - Jaccard_coef: 0.6220 - val_loss: 0.1484 - val_accuracy: 0.9689 - val_dice_coef: 0.7551 - val_Jaccard_coef: 0.6067
# Epoch 88/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9709 - dice_coef: 0.7669 - Jaccard_coef: 0.6220
# Epoch 88: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1377 - accuracy: 0.9709 - dice_coef: 0.7669 - Jaccard_coef: 0.6220 - val_loss: 0.1481 - val_accuracy: 0.9690 - val_dice_coef: 0.7560 - val_Jaccard_coef: 0.6078
# Epoch 89/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9708 - dice_coef: 0.7659 - Jaccard_coef: 0.6207
# Epoch 89: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1383 - accuracy: 0.9708 - dice_coef: 0.7659 - Jaccard_coef: 0.6207 - val_loss: 0.1488 - val_accuracy: 0.9693 - val_dice_coef: 0.7564 - val_Jaccard_coef: 0.6084
# Epoch 90/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1377 - accuracy: 0.9709 - dice_coef: 0.7662 - Jaccard_coef: 0.6211
# Epoch 90: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1377 - accuracy: 0.9709 - dice_coef: 0.7662 - Jaccard_coef: 0.6211 - val_loss: 0.1494 - val_accuracy: 0.9695 - val_dice_coef: 0.7580 - val_Jaccard_coef: 0.6104
# Epoch 91/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9710 - dice_coef: 0.7672 - Jaccard_coef: 0.6223
# Epoch 91: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1375 - accuracy: 0.9710 - dice_coef: 0.7672 - Jaccard_coef: 0.6223 - val_loss: 0.1491 - val_accuracy: 0.9687 - val_dice_coef: 0.7544 - val_Jaccard_coef: 0.6058
# Epoch 92/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1374 - accuracy: 0.9710 - dice_coef: 0.7674 - Jaccard_coef: 0.6226
# Epoch 92: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1374 - accuracy: 0.9710 - dice_coef: 0.7674 - Jaccard_coef: 0.6226 - val_loss: 0.1497 - val_accuracy: 0.9686 - val_dice_coef: 0.7513 - val_Jaccard_coef: 0.6018
# Epoch 93/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1381 - accuracy: 0.9709 - dice_coef: 0.7662 - Jaccard_coef: 0.6211
# Epoch 93: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1381 - accuracy: 0.9709 - dice_coef: 0.7662 - Jaccard_coef: 0.6211 - val_loss: 0.1494 - val_accuracy: 0.9687 - val_dice_coef: 0.7550 - val_Jaccard_coef: 0.6066
# Epoch 94/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9708 - dice_coef: 0.7664 - Jaccard_coef: 0.6213
# Epoch 94: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1379 - accuracy: 0.9708 - dice_coef: 0.7664 - Jaccard_coef: 0.6213 - val_loss: 0.1520 - val_accuracy: 0.9688 - val_dice_coef: 0.7448 - val_Jaccard_coef: 0.5935
# Epoch 95/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9710 - dice_coef: 0.7669 - Jaccard_coef: 0.6219
# Epoch 95: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1376 - accuracy: 0.9710 - dice_coef: 0.7669 - Jaccard_coef: 0.6219 - val_loss: 0.1486 - val_accuracy: 0.9686 - val_dice_coef: 0.7545 - val_Jaccard_coef: 0.6059
# Epoch 96/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9710 - dice_coef: 0.7672 - Jaccard_coef: 0.6223
# Epoch 96: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1372 - accuracy: 0.9710 - dice_coef: 0.7672 - Jaccard_coef: 0.6223 - val_loss: 0.1481 - val_accuracy: 0.9689 - val_dice_coef: 0.7551 - val_Jaccard_coef: 0.6067
# Epoch 97/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1373 - accuracy: 0.9710 - dice_coef: 0.7670 - Jaccard_coef: 0.6221
# Epoch 97: val_loss did not improve from 0.14803
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1373 - accuracy: 0.9710 - dice_coef: 0.7670 - Jaccard_coef: 0.6221 - val_loss: 0.1503 - val_accuracy: 0.9693 - val_dice_coef: 0.7548 - val_Jaccard_coef: 0.6064
# Epoch 98/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9710 - dice_coef: 0.7674 - Jaccard_coef: 0.6227
# Epoch 103: val_loss did not improve from 0.14801
# 44/44 [==============================] - 10s 225ms/step - loss: 0.1371 - accuracy: 0.9710 - dice_coef: 0.7674 - Jaccard_coef: 0.6227 - val_loss: 0.1484 - val_accuracy: 0.9692 - val_dice_coef: 0.7555 - val_Jaccard_coef: 0.6072
# Epoch 104/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1369 - accuracy: 0.9711 - dice_coef: 0.7682 - Jaccard_coef: 0.6237
# Epoch 104: val_loss improved from 0.14801 to 0.14794, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 11s 242ms/step - loss: 0.1369 - accuracy: 0.9711 - dice_coef: 0.7682 - Jaccard_coef: 0.6237 - val_loss: 0.1479 - val_accuracy: 0.9689 - val_dice_coef: 0.7585 - val_Jaccard_coef: 0.6112
# Epoch 105/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1372 - accuracy: 0.9710 - dice_coef: 0.7676 - Jaccard_coef: 0.6229
# Epoch 105: val_loss did not improve from 0.14794
# 44/44 [==============================] - 10s 227ms/step - loss: 0.1372 - accuracy: 0.9710 - dice_coef: 0.7676 - Jaccard_coef: 0.6229 - val_loss: 0.1483 - val_accuracy: 0.9691 - val_dice_coef: 0.7549 - val_Jaccard_coef: 0.6064
# Epoch 106/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9711 - dice_coef: 0.7676 - Jaccard_coef: 0.6230
# Epoch 106: val_loss improved from 0.14794 to 0.14744, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 10s 233ms/step - loss: 0.1368 - accuracy: 0.9711 - dice_coef: 0.7676 - Jaccard_coef: 0.6230 - val_loss: 0.1474 - val_accuracy: 0.9694 - val_dice_coef: 0.7541 - val_Jaccard_coef: 0.6054
# Epoch 107/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9712 - dice_coef: 0.7696 - Jaccard_coef: 0.6255
# Epoch 107: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 229ms/step - loss: 0.1362 - accuracy: 0.9712 - dice_coef: 0.7696 - Jaccard_coef: 0.6255 - val_loss: 0.1479 - val_accuracy: 0.9695 - val_dice_coef: 0.7571 - val_Jaccard_coef: 0.6092
# Epoch 108/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9710 - dice_coef: 0.7677 - Jaccard_coef: 0.6231
# Epoch 108: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1370 - accuracy: 0.9710 - dice_coef: 0.7677 - Jaccard_coef: 0.6231 - val_loss: 0.1487 - val_accuracy: 0.9689 - val_dice_coef: 0.7561 - val_Jaccard_coef: 0.6081
# Epoch 109/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9712 - dice_coef: 0.7696 - Jaccard_coef: 0.6255
# Epoch 109: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1361 - accuracy: 0.9712 - dice_coef: 0.7696 - Jaccard_coef: 0.6255 - val_loss: 0.1497 - val_accuracy: 0.9693 - val_dice_coef: 0.7586 - val_Jaccard_coef: 0.6113
# Epoch 110/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1364 - accuracy: 0.9712 - dice_coef: 0.7689 - Jaccard_coef: 0.6246
# Epoch 110: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1364 - accuracy: 0.9712 - dice_coef: 0.7689 - Jaccard_coef: 0.6246 - val_loss: 0.1503 - val_accuracy: 0.9693 - val_dice_coef: 0.7554 - val_Jaccard_coef: 0.6071
# Epoch 111/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1362 - accuracy: 0.9712 - dice_coef: 0.7691 - Jaccard_coef: 0.6249
# Epoch 111: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1362 - accuracy: 0.9712 - dice_coef: 0.7691 - Jaccard_coef: 0.6249 - val_loss: 0.1479 - val_accuracy: 0.9692 - val_dice_coef: 0.7551 - val_Jaccard_coef: 0.6067
# Epoch 112/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9711 - dice_coef: 0.7685 - Jaccard_coef: 0.6241
# Epoch 112: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1367 - accuracy: 0.9711 - dice_coef: 0.7685 - Jaccard_coef: 0.6241 - val_loss: 0.1508 - val_accuracy: 0.9694 - val_dice_coef: 0.7609 - val_Jaccard_coef: 0.6143
# Epoch 113/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9711 - dice_coef: 0.7680 - Jaccard_coef: 0.6234
# Epoch 113: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 230ms/step - loss: 0.1367 - accuracy: 0.9711 - dice_coef: 0.7680 - Jaccard_coef: 0.6234 - val_loss: 0.1480 - val_accuracy: 0.9690 - val_dice_coef: 0.7560 - val_Jaccard_coef: 0.6078
# Epoch 114/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9712 - dice_coef: 0.7694 - Jaccard_coef: 0.6253
# Epoch 114: val_loss did not improve from 0.14744
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1361 - accuracy: 0.9712 - dice_coef: 0.7694 - Jaccard_coef: 0.6253 - val_loss: 0.1481 - val_accuracy: 0.9694 - val_dice_coef: 0.7563 - val_Jaccard_coef: 0.6083
# Epoch 115/300
# ...
# Epoch 263/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7780 - Jaccard_coef: 0.6367
# Epoch 263: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7780 - Jaccard_coef: 0.6367 - val_loss: 0.1470 - val_accuracy: 0.9697 - val_dice_coef: 0.7631 - val_Jaccard_coef: 0.6171
# Epoch 264/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358
# Epoch 264: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358 - val_loss: 0.1462 - val_accuracy: 0.9693 - val_dice_coef: 0.7627 - val_Jaccard_coef: 0.6166
# Epoch 265/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7778 - Jaccard_coef: 0.6365
# Epoch 265: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7778 - Jaccard_coef: 0.6365 - val_loss: 0.1458 - val_accuracy: 0.9700 - val_dice_coef: 0.7607 - val_Jaccard_coef: 0.6140
# Epoch 266/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7787 - Jaccard_coef: 0.6376
# Epoch 266: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7787 - Jaccard_coef: 0.6376 - val_loss: 0.1467 - val_accuracy: 0.9700 - val_dice_coef: 0.7659 - val_Jaccard_coef: 0.6208
# Epoch 267/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7776 - Jaccard_coef: 0.6361
# Epoch 267: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7776 - Jaccard_coef: 0.6361 - val_loss: 0.1463 - val_accuracy: 0.9700 - val_dice_coef: 0.7644 - val_Jaccard_coef: 0.6188
# Epoch 268/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358
# Epoch 268: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358 - val_loss: 0.1466 - val_accuracy: 0.9698 - val_dice_coef: 0.7616 - val_Jaccard_coef: 0.6152
# Epoch 269/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7778 - Jaccard_coef: 0.6365
# Epoch 269: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7778 - Jaccard_coef: 0.6365 - val_loss: 0.1463 - val_accuracy: 0.9693 - val_dice_coef: 0.7581 - val_Jaccard_coef: 0.6105
# Epoch 270/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7780 - Jaccard_coef: 0.6367
# Epoch 270: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7780 - Jaccard_coef: 0.6367 - val_loss: 0.1459 - val_accuracy: 0.9699 - val_dice_coef: 0.7621 - val_Jaccard_coef: 0.6158
# Epoch 271/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7784 - Jaccard_coef: 0.6373
# Epoch 271: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7784 - Jaccard_coef: 0.6373 - val_loss: 0.1461 - val_accuracy: 0.9698 - val_dice_coef: 0.7592 - val_Jaccard_coef: 0.6120
# Epoch 272/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7774 - Jaccard_coef: 0.6360
# Epoch 272: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1306 - accuracy: 0.9724 - dice_coef: 0.7774 - Jaccard_coef: 0.6360 - val_loss: 0.1465 - val_accuracy: 0.9700 - val_dice_coef: 0.7652 - val_Jaccard_coef: 0.6199
# Epoch 273/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6370
# Epoch 273: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6370 - val_loss: 0.1466 - val_accuracy: 0.9697 - val_dice_coef: 0.7543 - val_Jaccard_coef: 0.6058
# Epoch 274/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6371
# Epoch 274: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6371 - val_loss: 0.1457 - val_accuracy: 0.9698 - val_dice_coef: 0.7589 - val_Jaccard_coef: 0.6117
# Epoch 275/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7786 - Jaccard_coef: 0.6375
# Epoch 275: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1304 - accuracy: 0.9725 - dice_coef: 0.7786 - Jaccard_coef: 0.6375 - val_loss: 0.1464 - val_accuracy: 0.9694 - val_dice_coef: 0.7587 - val_Jaccard_coef: 0.6114
# Epoch 276/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7778 - Jaccard_coef: 0.6364
# Epoch 276: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7778 - Jaccard_coef: 0.6364 - val_loss: 0.1464 - val_accuracy: 0.9698 - val_dice_coef: 0.7601 - val_Jaccard_coef: 0.6132
# Epoch 277/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6373
# Epoch 277: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6373 - val_loss: 0.1459 - val_accuracy: 0.9696 - val_dice_coef: 0.7587 - val_Jaccard_coef: 0.6114
# Epoch 278/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7776 - Jaccard_coef: 0.6362
# Epoch 278: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7776 - Jaccard_coef: 0.6362 - val_loss: 0.1479 - val_accuracy: 0.9698 - val_dice_coef: 0.7604 - val_Jaccard_coef: 0.6136
# Epoch 279/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1311 - accuracy: 0.9723 - dice_coef: 0.7774 - Jaccard_coef: 0.6360
# Epoch 279: val_loss did not improve from 0.14562
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1311 - accuracy: 0.9723 - dice_coef: 0.7774 - Jaccard_coef: 0.6360 - val_loss: 0.1467 - val_accuracy: 0.9694 - val_dice_coef: 0.7552 - val_Jaccard_coef: 0.6068
# Epoch 280/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358
# Epoch 280: val_loss improved from 0.14562 to 0.14555, saving model to /homes/imransharif/Mehwish/Year 3/Mamba_Block/AV_weights/RetinaNet-Hybrid_Attention_New-Combined_DRIVE-Final.h5
# 44/44 [==============================] - 14s 312ms/step - loss: 0.1307 - accuracy: 0.9724 - dice_coef: 0.7773 - Jaccard_coef: 0.6358 - val_loss: 0.1456 - val_accuracy: 0.9697 - val_dice_coef: 0.7601 - val_Jaccard_coef: 0.6132
# Epoch 281/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9723 - dice_coef: 0.7778 - Jaccard_coef: 0.6364
# Epoch 281: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1310 - accuracy: 0.9723 - dice_coef: 0.7778 - Jaccard_coef: 0.6364 - val_loss: 0.1467 - val_accuracy: 0.9691 - val_dice_coef: 0.7613 - val_Jaccard_coef: 0.6148
# Epoch 282/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7779 - Jaccard_coef: 0.6366
# Epoch 282: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7779 - Jaccard_coef: 0.6366 - val_loss: 0.1460 - val_accuracy: 0.9697 - val_dice_coef: 0.7629 - val_Jaccard_coef: 0.6168
# Epoch 283/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378
# Epoch 283: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1300 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378 - val_loss: 0.1456 - val_accuracy: 0.9701 - val_dice_coef: 0.7652 - val_Jaccard_coef: 0.6199
# Epoch 284/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1301 - accuracy: 0.9726 - dice_coef: 0.7786 - Jaccard_coef: 0.6375
# Epoch 284: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1301 - accuracy: 0.9726 - dice_coef: 0.7786 - Jaccard_coef: 0.6375 - val_loss: 0.1474 - val_accuracy: 0.9691 - val_dice_coef: 0.7576 - val_Jaccard_coef: 0.6100
# Epoch 285/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9725 - dice_coef: 0.7789 - Jaccard_coef: 0.6379
# Epoch 285: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1300 - accuracy: 0.9725 - dice_coef: 0.7789 - Jaccard_coef: 0.6379 - val_loss: 0.1462 - val_accuracy: 0.9700 - val_dice_coef: 0.7646 - val_Jaccard_coef: 0.6190
# Epoch 286/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6374
# Epoch 286: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6374 - val_loss: 0.1462 - val_accuracy: 0.9699 - val_dice_coef: 0.7631 - val_Jaccard_coef: 0.6171
# Epoch 287/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9725 - dice_coef: 0.7778 - Jaccard_coef: 0.6365
# Epoch 287: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1306 - accuracy: 0.9725 - dice_coef: 0.7778 - Jaccard_coef: 0.6365 - val_loss: 0.1467 - val_accuracy: 0.9691 - val_dice_coef: 0.7559 - val_Jaccard_coef: 0.6078
# Epoch 288/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7786 - Jaccard_coef: 0.6375
# Epoch 288: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7786 - Jaccard_coef: 0.6375 - val_loss: 0.1459 - val_accuracy: 0.9699 - val_dice_coef: 0.7647 - val_Jaccard_coef: 0.6192
# Epoch 289/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6374
# Epoch 289: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7785 - Jaccard_coef: 0.6374 - val_loss: 0.1469 - val_accuracy: 0.9694 - val_dice_coef: 0.7622 - val_Jaccard_coef: 0.6160
# Epoch 290/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7777 - Jaccard_coef: 0.6364
# Epoch 290: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1303 - accuracy: 0.9725 - dice_coef: 0.7777 - Jaccard_coef: 0.6364 - val_loss: 0.1464 - val_accuracy: 0.9700 - val_dice_coef: 0.7633 - val_Jaccard_coef: 0.6174
# Epoch 291/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7779 - Jaccard_coef: 0.6366
# Epoch 291: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1310 - accuracy: 0.9724 - dice_coef: 0.7779 - Jaccard_coef: 0.6366 - val_loss: 0.1475 - val_accuracy: 0.9692 - val_dice_coef: 0.7542 - val_Jaccard_coef: 0.6056
# Epoch 292/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6370
# Epoch 292: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1305 - accuracy: 0.9725 - dice_coef: 0.7782 - Jaccard_coef: 0.6370 - val_loss: 0.1460 - val_accuracy: 0.9697 - val_dice_coef: 0.7653 - val_Jaccard_coef: 0.6200
# Epoch 293/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1297 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378
# Epoch 293: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1297 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378 - val_loss: 0.1458 - val_accuracy: 0.9698 - val_dice_coef: 0.7668 - val_Jaccard_coef: 0.6219
# Epoch 294/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9724 - dice_coef: 0.7777 - Jaccard_coef: 0.6363
# Epoch 294: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1309 - accuracy: 0.9724 - dice_coef: 0.7777 - Jaccard_coef: 0.6363 - val_loss: 0.1463 - val_accuracy: 0.9700 - val_dice_coef: 0.7640 - val_Jaccard_coef: 0.6183
# Epoch 295/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7791 - Jaccard_coef: 0.6381
# Epoch 295: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7791 - Jaccard_coef: 0.6381 - val_loss: 0.1469 - val_accuracy: 0.9700 - val_dice_coef: 0.7674 - val_Jaccard_coef: 0.6227
# Epoch 296/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9726 - dice_coef: 0.7792 - Jaccard_coef: 0.6384
# Epoch 296: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1299 - accuracy: 0.9726 - dice_coef: 0.7792 - Jaccard_coef: 0.6384 - val_loss: 0.1470 - val_accuracy: 0.9699 - val_dice_coef: 0.7598 - val_Jaccard_coef: 0.6128
# Epoch 297/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378
# Epoch 297: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7788 - Jaccard_coef: 0.6378 - val_loss: 0.1457 - val_accuracy: 0.9700 - val_dice_coef: 0.7678 - val_Jaccard_coef: 0.6233
# Epoch 298/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7790 - Jaccard_coef: 0.6380
# Epoch 298: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1302 - accuracy: 0.9725 - dice_coef: 0.7790 - Jaccard_coef: 0.6380 - val_loss: 0.1469 - val_accuracy: 0.9702 - val_dice_coef: 0.7628 - val_Jaccard_coef: 0.6168
# Epoch 299/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7792 - Jaccard_coef: 0.6383
# Epoch 299: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1298 - accuracy: 0.9726 - dice_coef: 0.7792 - Jaccard_coef: 0.6383 - val_loss: 0.1468 - val_accuracy: 0.9698 - val_dice_coef: 0.7628 - val_Jaccard_coef: 0.6167
# Epoch 300/300
# 44/44 [==============================] - ETA: 0s - loss: 0.1296 - accuracy: 0.9727 - dice_coef: 0.7794 - Jaccard_coef: 0.6386
# Epoch 300: val_loss did not improve from 0.14555
# 44/44 [==============================] - 10s 231ms/step - loss: 0.1296 - accuracy: 0.9727 - dice_coef: 0.7794 - Jaccard_coef: 0.6386 - val_loss: 0.1463 - val_accuracy: 0.9697 - val_dice_coef: 0.7590 - val_Jaccard_coef: 0.6118

# %%
# Modifying the code for a single output
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
# Assuming results.history['loss'] and results.history['val_loss'] correspond to the single output loss
plt.plot(results.history["accuracy"], label="Accuracy")
plt.plot(results.history["val_accuracy"], label="Validation Accuracy")

plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.legend()
plt.show()

# %%
# Modifying the code for a single output
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
# Assuming results.history['loss'] and results.history['val_loss'] correspond to the single output loss
plt.plot(results.history["dice_coef"], label="dice_coef")
plt.plot(results.history["val_dice_coef"], label="Validation dice_coef")

plt.xlabel("Epochs")
plt.ylabel("dice_coef")
plt.legend()
plt.show()

# %%
# Modifying the code for a single output
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
# Assuming results.history['loss'] and results.history['val_loss'] correspond to the single output loss
plt.plot(results.history["loss"], label="Training Loss")
plt.plot(results.history["val_loss"], label="Validation Loss")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
def evaluate_metrics(y_test, y_pred):
    n = y_pred.shape[0]
    all_F1_score = np.zeros(n)
    all_dice = np.zeros(n)
    all_jaccard = np.zeros(n)
    all_sensitivity = np.zeros(n)
    all_specificity = np.zeros(n)
    for i in range(n):
        gt, pred = y_test[i], y_pred[i]
        gt_flt = np.ndarray.flatten(gt)
        pred_flt = np.ndarray.flatten(pred)

        precisions, recalls, thresholds = precision_recall_curve(gt_flt, pred_flt)
        f1 = 2*(precisions * recalls) / (precisions + recalls)
        max_value = np.argmax(f1)
        thres = thresholds[max_value]
        pred_mask = (pred_flt >= thres)
        pred_label = pred_mask*1

        tn, fp, fn, tp = confusion_matrix(gt_flt, pred_label).ravel()

        F1_score = tp/(tp+((0.5)*(fp+fn)))
        iou = tp / (tp + fp + fn)
        dice = 2*tp / (2*tp + fp + fn)
        specificity = tn / (tn + fp)
        recall = tp / (tp + fn)

        all_F1_score[i] = F1_score
        all_dice[i] = dice
        all_jaccard[i] = iou
        all_sensitivity[i] = recall
        all_specificity[i] = specificity

        print(' F1_score: {:4f}, Dice: {:4f}, Jaccard: {:4f}, Sensitivity: {:4f}, Specificity: {:4f}'.format(
        np.nanmean(all_F1_score), np.nanmean(all_dice), np.nanmean(all_jaccard), np.nanmean(all_sensitivity), np.nanmean(all_specificity)
        ))
    return all_F1_score, all_dice, all_jaccard, all_sensitivity, all_specificity

# %%
# model.save_weights('/homes/imransharif/Mehwish/DRIVE/AV_weights/FR_UNet_RAAM_DRIVE.h5')

# %%
# valid_data = '/content/ISIC2018_256x256/test' #data path
X_test, y_test = get_data(valid_data)
# Out:
# Getting and resizing images ...
# Done!

# %%
from sklearn.metrics import precision_recall_curve
import warnings
warnings.filterwarnings("ignore")

def evaluate_metrics(y_test, y_pred, return_mode='all'):
    n = y_pred.shape[0]
    all_accuracy = np.zeros(n)
    all_dice = np.zeros(n)
    all_jaccard = np.zeros(n)
    all_sensitivity = np.zeros(n)
    all_specificity = np.zeros(n)
    for i in range(n):
        gt, pred = y_test[i], y_pred[i]
        gt_flt = np.ndarray.flatten(gt)
        pred_flt = np.ndarray.flatten(pred)

        precisions, recalls, thresholds = precision_recall_curve(gt_flt, pred_flt)
        f1 = 2*(precisions * recalls) / (precisions + recalls)
        max_value = np.argmax(f1)
        precision, recall, thres = precisions[max_value], recalls[max_value], thresholds[max_value]

        maxval = 255
        pred_mask = (pred_flt > thres)
        pred_label = pred_mask*1

        tn, fp, fn, tp = confusion_matrix(gt_flt, pred_label).ravel()

        accuracy = (tp + tn) / (tp + tn + fp + fn)
        iou = tp / (tp + fp + fn)
        dice = 2*tp / (2*tp + fp + fn)
        specificity = tn / (tn + fp)

        all_accuracy[i] = accuracy
        all_dice[i] = dice
        all_jaccard[i] = iou
        all_sensitivity[i] = recall
        all_specificity[i] = specificity

    print('Accuracy: {:4f}, Dice: {:4f}, Jaccard: {:4f}, Sensitivity: {:4f}, Specificity: {:4f}'.format(
        np.nanmean(all_accuracy), np.nanmean(all_dice), np.nanmean(all_jaccard), np.nanmean(all_sensitivity), np.nanmean(all_specificity)
    ))
    if return_mode == 'all':
        return all_accuracy, all_dice, all_jaccard, all_sensitivity, all_specificity
    if return_mode == 'value':
        return np.nanmean(all_accuracy), np.nanmean(all_dice), np.nanmean(all_jaccard), np.nanmean(all_sensitivity), np.nanmean(all_specificity)
    else:
        return 'No val returned'

# %%
# Convert ground truth labels to binary
y_test_BV = (y_test[0] > 0.5).astype(np.uint8)
# y_test_OD = (y_test[1] > 0.5).astype(np.uint8)

y_pred = model.predict(X_test, batch_size =1 ,verbose=1)

# y_pred = model.predict(X_test)
# evl = evaluate_metrics(y_test_BV, y_pred, return_mode='all')
# Out:
# 20/20 [==============================] - 2s 7ms/step

# %%
# Convert model's outputs to binary
predictions_BV = (y_pred[0] > 0.5).astype(np.uint8)
# predictions_OD = (predictions[1] > 0.5).astype(np.uint8)

# %%
memory_usage = model.count_params() * 4  # Assuming float32 data type (4 bytes per parameter)
print("Memory Usage: {:.2f} MB".format(memory_usage / 1024 / 1024))  # Divide by 1024 twice to convert from bytes to KB, then KB to MB
# Out:
# Memory Usage: 0.42 MB

# %%
#   !pip install keras-flops
  from keras_flops import get_flops

  flops = get_flops(model)
  print(f"FLOPs: {flops / 10**9:.03} G")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# Requirement already satisfied: keras-flops in /homes/imransharif/.local/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from keras-flops) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/software/software/flatbuffers/2.0.7-GCCcore-11.3.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (20240208003218)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /opt/software/software/h5py/3.7.0-foss-2022a/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.7.0)
# Requirement already satisfied: numpy>=1.20 in /opt/software/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.22.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: packaging in /homes/imransharif/.local/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (21.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /opt/software/software/protobuf-python/3.19.4-GCCcore-11.3.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.19.4)
# Requirement already satisfied: setuptools in /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (62.1.0)
# Requirement already satisfied: six>=1.12.0 in /homes/imransharif/.local/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /homes/imransharif/.local/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (4.13.2)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.51.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.11.1)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.11.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow<3.0,>=2.2->keras-flops) (0.37.1)
# Requirement already satisfied: mpi4py>=3.0.2 in /opt/software/software/SciPy-bundle/2022.05-foss-2022a/lib/python3.10/site-packages (from h5py>=2.9.0->tensorflow<3.0,>=2.2->keras-flops) (3.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2.16.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /homes/imransharif/.local/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /homes/imransharif/.local/lib/python3.10/site-packages (from packaging->tensorflow<3.0,>=2.2->keras-flops) (3.0.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /homes/imransharif/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /homes/imransharif/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /homes/imransharif/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2022.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/software/software/Python/3.10.4-GCCcore-11.3.0/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow<3.0,>=2.2->keras-flops) (3.2.2)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -andas (/homes/imransharif/.local/lib/python3.10/site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (/homes/imransharif/.local/lib/python3.10/site-packages)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1
# [notice] To update, run: pip install --upgrade pip
# WARNING:tensorflow:From /opt/software/software/TensorFlow/2.11.0-foss-2022a-CUDA-11.7.0/lib/python3.10/site-packages/tensorflow/python/ops/nn_ops.py:5250: tensor_shape_from_node_def_name (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
#
# =========================Options=============================
# -max_depth                  10000
# -min_bytes                  0
# -min_peak_bytes             0
# -min_residual_bytes         0
# -min_output_bytes           0
# -min_micros                 0
# -min_accelerator_micros     0
# -min_cpu_micros             0
# -min_params                 0
# -min_float_ops              1
# -min_occurrence             0
# -step                       -1
# -order_by                   float_ops
# -account_type_regexes       .*
# -start_name_regexes         .*
# -trim_name_regexes
# -show_name_regexes          .*
# -hide_name_regexes
# -account_displayed_op_only  true
# -select                     float_ops
# -output                     stdout:
#
# ==================Model Analysis Report======================
#
# Doc:
# scope: The nodes in the model graph are organized by their names, which is hierarchical like filesystem.
# flops: Number of float operations. Note: Please read the implementation for the math behind it.
#
# ProfiFLOPs: 4.46 G
